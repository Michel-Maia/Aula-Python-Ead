# %%
import seaborn as sns

# %% [markdown]
# Função countplot
#
# esse método não aceita que sejam passados valores de x e y ao mesmo tempo

# %%
df = sns.load_dataset("titanic")
sns.countplot(x=df["class"])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# Função scartterplot()

# %% [markdown]
# os gráficos de grupo relacional permitem avaliar, de forma visual a relação entre duas variáveis x,y
#
# usado para busca de padrões nos dados

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
